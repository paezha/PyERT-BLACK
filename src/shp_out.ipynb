# %%
import geopandas as gpd

rc_shp = gpd.read_file('/Users/jasperleung/Desktop/demo/route_choice/route_choice.shp')
rc_shp
# Out:
#    SerialID                                           geometry
# 0        26  LINESTRING (-79.78819 43.33571, -79.78818 43.3...

# %%
al_shp= gpd.read_file('/Users/jasperleung/Desktop/demo/activity_locations_info/activity_locations_info.shp')
al_shp
# Out:
#      SerialID  RecordID       TimeStart Modes house_numb       street_nam  \
# 0          26      6009  9/3/2009 12:04  Stop        NaN              NaN
# 1          26      6010  9/3/2009 12:08  Stop        NaN              NaN
# 2          26      6011  9/3/2009 12:08  Stop        NaN              NaN
# 3          26      6012  9/3/2009 12:08  Stop        NaN              NaN
# 4          26      6013  9/3/2009 12:08  Stop        NaN              NaN
# ..        ...       ...             ...   ...        ...              ...
# 109        26     14748  9/3/2009 16:13  Stop       2445  Woodward Avenue
# 110        26     14749  9/3/2009 16:13  Stop       2445  Woodward Avenue
# 111        26     14750  9/3/2009 16:13  Stop       2445  Woodward Avenue
# 112        26     14751  9/3/2009 16:13  Stop       2445  Woodward Avenue
# 113        26     14752  9/3/2009 16:13  Stop       2445  Woodward Avenue
#
#            city  province                               name_of_bu  \
# 0           NaN       NaN  Rosemount Apartments & Executive Suites
# 1           NaN       NaN  Rosemount Apartments & Executive Suites
# 2           NaN       NaN  Rosemount Apartments & Executive Suites
# 3           NaN       NaN  Rosemount Apartments & Executive Suites
# 4           NaN       NaN  Rosemount Apartments & Executive Suites
# ..          ...       ...                                      ...
# 109  Burlington       NaN                      Victoria Apartments
# 110  Burlington       NaN                      Victoria Apartments
# 111  Burlington       NaN                      Victoria Apartments
# 112  Burlington       NaN                      Victoria Apartments
# 113  Burlington       NaN                      Victoria Apartments
#
#       lu_classif                                           geometry
# 0    residential  POLYGON ((-79.78640 43.33578, -79.78664 43.335...
# 1    residential  POLYGON ((-79.78640 43.33578, -79.78664 43.335...
# 2    residential  POLYGON ((-79.78640 43.33578, -79.78664 43.335...
# 3    residential  POLYGON ((-79.78640 43.33578, -79.78664 43.335...
# 4    residential  POLYGON ((-79.78640 43.33578, -79.78664 43.335...
# ..           ...                                                ...
# 109  residential  POLYGON ((-79.79213 43.34194, -79.79227 43.342...
# 110  residential  POLYGON ((-79.79213 43.34194, -79.79227 43.342...
# 111  residential  POLYGON ((-79.79213 43.34194, -79.79227 43.342...
# 112  residential  POLYGON ((-79.79213 43.34194, -79.79227 43.342...
# 113  residential  POLYGON ((-79.79213 43.34194, -79.79227 43.342...
#
# [114 rows x 11 columns]
